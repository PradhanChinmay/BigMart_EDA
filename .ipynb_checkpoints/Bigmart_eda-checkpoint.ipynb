# %%
# Installing opendatasets library

# !pip install jovian opendatasets --upgrade --quiet
# Out:
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Importing the required libraries

import opendatasets as od
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
od.download("https://www.kaggle.com/datasets/thedevastator/bigmart-product-sales-factors")
# Out:
# Skipping, found downloaded files in ".\bigmart-product-sales-factors" (use force=True to force download)

# %%
bigmart_df=pd.read_csv("bigmart-product-sales-factors/data.csv")
bigmart_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           2009      Medium               Tier 3
# 2                           1999      Medium               Tier 1
# 3                           1998         NaN               Tier 3
# 4                           1987        High               Tier 3
# ...                          ...         ...                  ...
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# 14201                       2002         NaN               Tier 2
# 14202                       2007         NaN               Tier 2
# 14203                       2002         NaN               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales
# 0      Supermarket Type1        3735.138000
# 1      Supermarket Type2         443.422800
# 2      Supermarket Type1        2097.270000
# 3          Grocery Store         732.380000
# 4      Supermarket Type1         994.705200
# ...                  ...                ...
# 14199  Supermarket Type1        2213.476465
# 14200  Supermarket Type2        2349.547110
# 14201  Supermarket Type1        1892.981544
# 14202  Supermarket Type1        4533.564958
# 14203  Supermarket Type1        1302.235520
#
# [14204 rows x 12 columns]

# %%
bigmart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
bigmart_df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
bigmart_df.shape
# Out:
# (14204, 12)

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
itemWeight_Mean=bigmart_df['Item_Weight'].mean()
itemWeight_Mean
# Out:
# 12.792854228644284

# %%
bigmart_df['Item_Weight']=bigmart_df['Item_Weight'].fillna(itemWeight_Mean)

# %%
bigmart_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           2009      Medium               Tier 3
# 2                           1999      Medium               Tier 1
# 3                           1998         NaN               Tier 3
# 4                           1987        High               Tier 3
# ...                          ...         ...                  ...
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# 14201                       2002         NaN               Tier 2
# 14202                       2007         NaN               Tier 2
# 14203                       2002         NaN               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales
# 0      Supermarket Type1        3735.138000
# 1      Supermarket Type2         443.422800
# 2      Supermarket Type1        2097.270000
# 3          Grocery Store         732.380000
# 4      Supermarket Type1         994.705200
# ...                  ...                ...
# 14199  Supermarket Type1        2213.476465
# 14200  Supermarket Type2        2349.547110
# 14201  Supermarket Type1        1892.981544
# 14202  Supermarket Type1        4533.564958
# 14203  Supermarket Type1        1302.235520
#
# [14204 rows x 12 columns]

# %%
bigmart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
missing_columns = bigmart_df.columns[bigmart_df.isnull().any()].tolist()
impute_data = bigmart_df[missing_columns]

# %%
no_missing_data = bigmart_df.drop(missing_columns, axis = 1)

# %%
knn_imputer = KNNImputer(n_neighbors = 5)

# %%
imputed_data=pd.DataFrame()
for column in missing_columns:
    if impute_data[column].isnull().any():
        impute_data_numeric = pd.get_dummies(impute_data[column])
        
        imputed_data_numeric = pd.DataFrame(knn_imputer.fit_transform(impute_data_numeric), columns=impute_data_numeric.columns)
        
        imputed_data[column] = imputed_data_numeric.idxmax(axis=1)
    else:
        imputed_data[column] = impute_data[column]

filled_data = pd.concat([no_missing_data, imputed_data], axis=1)

# %%
new_bigmart_df=filled_data

# %%
new_bigmart_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 0                           1999               Tier 1  Supermarket Type1
# 1                           2009               Tier 3  Supermarket Type2
# 2                           1999               Tier 1  Supermarket Type1
# 3                           1998               Tier 3      Grocery Store
# 4                           1987               Tier 3  Supermarket Type1
# ...                          ...                  ...                ...
# 14199                       1997               Tier 1  Supermarket Type1
# 14200                       2009               Tier 3  Supermarket Type2
# 14201                       2002               Tier 2  Supermarket Type1
# 14202                       2007               Tier 2  Supermarket Type1
# 14203                       2002               Tier 2  Supermarket Type1
#
#        Item_Outlet_Sales Outlet_Size
# 0            3735.138000      Medium
# 1             443.422800      Medium
# 2            2097.270000      Medium
# 3             732.380000        High
# 4             994.705200        High
# ...                  ...         ...
# 14199        2213.476465       Small
# 14200        2349.547110      Medium
# 14201        1892.981544        High
# 14202        4533.564958        High
# 14203        1302.235520        High
#
# [14204 rows x 12 columns]

# %%
columns = new_bigmart_df.columns.tolist()
columns.remove("Outlet_Size")

target_index = columns.index("Outlet_Establishment_Year")
columns.insert(target_index + 1, "Outlet_Size")

new_bigmart_df=new_bigmart_df[columns]

# %%
new_bigmart_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           2009      Medium               Tier 3
# 2                           1999      Medium               Tier 1
# 3                           1998        High               Tier 3
# 4                           1987        High               Tier 3
# ...                          ...         ...                  ...
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# 14201                       2002        High               Tier 2
# 14202                       2007        High               Tier 2
# 14203                       2002        High               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales
# 0      Supermarket Type1        3735.138000
# 1      Supermarket Type2         443.422800
# 2      Supermarket Type1        2097.270000
# 3          Grocery Store         732.380000
# 4      Supermarket Type1         994.705200
# ...                  ...                ...
# 14199  Supermarket Type1        2213.476465
# 14200  Supermarket Type2        2349.547110
# 14201  Supermarket Type1        1892.981544
# 14202  Supermarket Type1        4533.564958
# 14203  Supermarket Type1        1302.235520
#
# [14204 rows x 12 columns]

# %%
new_bigmart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
new_bigmart_df=new_bigmart_df.round(2)

# %%
new_bigmart_df.sample(10)
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 13268           FDT04        12.79          Low Fat             0.11
# 4490            FDW48        18.00          Low Fat             0.01
# 10782           NCW30         5.21          Low Fat             0.01
# 12070           DRC24        17.85          Low Fat             0.02
# 12125           NCW54        12.79          Low Fat             0.10
# 9809            FDT01        13.65          Regular             0.18
# 4460            FDM01         7.90          Regular             0.09
# 12654           FDZ03        13.65          Regular             0.08
# 5289            FDM04         9.20          Regular             0.05
# 9631            FDT50         6.75          Regular             0.18
#
#           Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 13268  Frozen Foods     38.18            OUT027                       1985
# 4490   Baking Goods     81.26            OUT035                       2004
# 10782     Household    258.80            OUT045                       2002
# 12070   Soft Drinks    151.80            OUT049                       1999
# 12125     Household     57.86            OUT027                       1985
# 9809         Canned    214.09            OUT035                       2004
# 4460      Breakfast    100.73            OUT013                       1987
# 12654         Dairy    187.62            OUT013                       1987
# 5289   Frozen Foods     53.17            OUT046                       1997
# 9631          Dairy     97.38            OUT010                       1998
#
#       Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 13268      Medium               Tier 3  Supermarket Type3             904.43
# 4490        Small               Tier 2  Supermarket Type1             402.81
# 10782        High               Tier 2  Supermarket Type1            3181.06
# 12070      Medium               Tier 1  Supermarket Type1            2297.40
# 12125      Medium               Tier 3  Supermarket Type3            1765.03
# 9809        Small               Tier 2  Supermarket Type1            3374.93
# 4460         High               Tier 3  Supermarket Type1            1230.40
# 12654        High               Tier 3  Supermarket Type1            3228.20
# 5289        Small               Tier 1  Supermarket Type1             769.00
# 9631         High               Tier 3      Grocery Store             184.80

# %%
new_bigmart_df["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
new_bigmart_df["Item_Fat_Content"]=new_bigmart_df["Item_Fat_Content"].replace(['low fat','LF'],'Low Fat')
new_bigmart_df["Item_Fat_Content"]=new_bigmart_df["Item_Fat_Content"].replace(['reg'],'Regular')

# %%
new_bigmart_df.sample(20)
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4119            NCA06        20.50          Low Fat             0.14
# 825             FDF46         7.07          Low Fat             0.09
# 10247           FDQ60        12.79          Regular             0.11
# 1321            NCY41        16.75          Low Fat             0.08
# 12814           FDY45        17.50          Low Fat             0.04
# 391             FDY32         7.60          Low Fat             0.13
# 3367            FDT10        16.70          Regular             0.06
# 10670           NCG07        12.30          Low Fat             0.05
# 5244            FDT37        14.15          Low Fat             0.04
# 14102           NCI29         8.60          Low Fat             0.03
# 4026            FDN21        12.79          Low Fat             0.13
# 6818            NCJ54         9.90          Low Fat             0.06
# 6531            FDE51         5.92          Regular             0.10
# 1677            FDZ08        12.50          Regular             0.11
# 9625            DRH13         8.57          Low Fat             0.02
# 7007            FDC16        11.50          Regular             0.02
# 5735            FDK20        12.79          Regular             0.07
# 9304            FDZ44         8.18          Low Fat             0.04
# 12067           FDY36        12.30          Low Fat             0.01
# 7460            FDN21        18.60          Low Fat             0.08
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 4119               Household     37.22            OUT045
# 825              Snack Foods    113.38            OUT035
# 10247           Baking Goods    118.51            OUT027
# 1321      Health and Hygiene     37.65            OUT045
# 12814            Snack Foods    252.94            OUT010
# 391    Fruits and Vegetables    164.02            OUT045
# 3367             Snack Foods     60.96            OUT013
# 10670              Household    188.65            OUT049
# 5244                  Canned    255.50            OUT013
# 14102     Health and Hygiene    140.62            OUT013
# 4026             Snack Foods    159.82            OUT019
# 6818               Household    233.06            OUT045
# 6531                   Dairy     45.61            OUT013
# 1677   Fruits and Vegetables     82.76            OUT035
# 9625             Soft Drinks    108.43            OUT035
# 7007                   Dairy     85.05            OUT017
# 5735   Fruits and Vegetables    120.91            OUT019
# 9304   Fruits and Vegetables    118.58            OUT013
# 12067           Baking Goods     74.54            OUT018
# 7460             Snack Foods    161.02            OUT013
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 4119                        2002        High               Tier 2
# 825                         2004       Small               Tier 2
# 10247                       1985      Medium               Tier 3
# 1321                        2002        High               Tier 2
# 12814                       1998        High               Tier 3
# 391                         2002        High               Tier 2
# 3367                        1987        High               Tier 3
# 10670                       1999      Medium               Tier 1
# 5244                        1987        High               Tier 3
# 14102                       1987        High               Tier 3
# 4026                        1985       Small               Tier 1
# 6818                        2002        High               Tier 2
# 6531                        1987        High               Tier 3
# 1677                        2004       Small               Tier 2
# 9625                        2004       Small               Tier 2
# 7007                        2007        High               Tier 2
# 5735                        1985       Small               Tier 1
# 9304                        1987        High               Tier 3
# 12067                       2009      Medium               Tier 3
# 7460                        1987        High               Tier 3
#
#              Outlet_Type  Item_Outlet_Sales
# 4119   Supermarket Type1             476.05
# 825    Supermarket Type1            1267.02
# 10247  Supermarket Type3            2997.60
# 1321   Supermarket Type1             575.25
# 12814      Grocery Store             399.22
# 391    Supermarket Type1            3914.90
# 3367   Supermarket Type1             355.54
# 10670  Supermarket Type1            3068.58
# 5244   Supermarket Type1            5355.03
# 14102  Supermarket Type1            1559.11
# 4026       Grocery Store             322.25
# 6818   Supermarket Type1            6041.47
# 6531   Supermarket Type1             356.87
# 1677   Supermarket Type1             577.91
# 9625   Supermarket Type1            1650.53
# 7007   Supermarket Type1            1731.08
# 5735       Grocery Store             122.51
# 9304   Supermarket Type1            1574.13
# 12067  Supermarket Type2             848.69
# 7460   Supermarket Type1            3705.84
