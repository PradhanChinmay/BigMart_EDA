# %%
# Installing opendatasets library

# !pip install jovian opendatasets --upgrade --quiet
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Importing the required libraries

import opendatasets as od
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
od.download("https://www.kaggle.com/datasets/thedevastator/bigmart-product-sales-factors")
# Out:
# Skipping, found downloaded files in ".\bigmart-product-sales-factors" (use force=True to force download)

# %%
bigmart_df=pd.read_csv("bigmart-product-sales-factors/data.csv")
bigmart_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
bigmart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
bigmart_df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
bigmart_df.shape
# Out:
# (14204, 12)

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
itemWeight_Mean=bigmart_df['Item_Weight'].mean()
itemWeight_Mean
# Out:
# 12.792854228644284

# %%
bigmart_df['Item_Weight']=bigmart_df['Item_Weight'].fillna(itemWeight_Mean)

# %%
bigmart_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
bigmart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
missing_columns = bigmart_df.columns[bigmart_df.isnull().any()].tolist()
impute_data = bigmart_df[missing_columns]

# %%
no_missing_data = bigmart_df.drop(missing_columns, axis = 1)

# %%
knn_imputer = KNNImputer(n_neighbors = 5)

# %%
imputed_data=pd.DataFrame()
for column in missing_columns:
    if impute_data[column].isnull().any():
        impute_data_numeric = pd.get_dummies(impute_data[column])
        
        imputed_data_numeric = pd.DataFrame(knn_imputer.fit_transform(impute_data_numeric), columns=impute_data_numeric.columns)
        
        imputed_data[column] = imputed_data_numeric.idxmax(axis=1)
    else:
        imputed_data[column] = impute_data[column]

filled_data = pd.concat([no_missing_data, imputed_data], axis=1)

# %%
new_bigmart_df=filled_data

# %%
new_bigmart_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
columns = new_bigmart_df.columns.tolist()
columns.remove("Outlet_Size")

target_index = columns.index("Outlet_Establishment_Year")
columns.insert(target_index + 1, "Outlet_Size")

new_bigmart_df=new_bigmart_df[columns]

# %%
new_bigmart_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
new_bigmart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
new_bigmart_df=new_bigmart_df.round(2)

# %%
new_bigmart_df.sample(10)
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8082            FDQ58         7.32          Low Fat             0.02
# 10557           FDB22         8.02          Low Fat             0.00
# 3952            FDR31         6.46          Regular             0.05
# 2584            FDQ16        19.70          Low Fat             0.04
# 10903           FDC22        12.79          Regular             0.24
# 3642            FDK33        17.85          Low Fat             0.01
# 13270           FDS56         5.78          Regular             0.04
# 2394            NCP55        14.65          Low Fat             0.00
# 4177            FDE11        17.70          Regular             0.14
# 10366           FDG21        17.35          Regular             0.15
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 8082             Snack Foods    154.03            OUT045
# 10557            Snack Foods    151.80            OUT018
# ...

# %%
new_bigmart_df["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
new_bigmart_df["Item_Fat_Content"]=new_bigmart_df["Item_Fat_Content"].replace(['low fat','LF'],'Low Fat')
new_bigmart_df["Item_Fat_Content"]=new_bigmart_df["Item_Fat_Content"].replace(['reg'],'Regular')

# %%
new_bigmart_df.sample(20)
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3749            FDY15        18.25          Regular             0.17
# 4535            DRM49         6.11          Regular             0.15
# 11888           FDL03        19.25          Regular             0.05
# 9838            FDZ36         6.04          Regular             0.07
# 2590            NCA06        20.50          Low Fat             0.00
# 12647           NCQ29        12.00          Low Fat             0.10
# 13228           DRH25        18.70          Low Fat             0.01
# 2819            DRE03        19.60          Low Fat             0.02
# 4985            FDT14        10.70          Regular             0.13
# 9597            FDA16         6.70          Low Fat             0.03
# 9892            FDX13         7.72          Low Fat             0.08
# 4993            DRH11         5.98          Low Fat             0.08
# 4183            FDQ26        13.50          Regular             0.07
# ...

# %% [markdown]
# ## Performing Exploratory Data Analysis

# %%
bigmart_df.Item_Outlet_Sales.sum().round()
# Out:
# 29818933.0

# %%
new_bigmart_df.groupby(['Outlet_Establishment_Year', 'Outlet_Identifier'])['Item_Outlet_Sales'].sum().reset_index().sort_values('Item_Outlet_Sales', ascending=True)
# Out:
#    Outlet_Establishment_Year Outlet_Identifier  Item_Outlet_Sales
# 0                       1985            OUT019          283302.64
# 4                       1998            OUT010          299023.88
# 9                       2009            OUT018         2979587.34
# 6                       2002            OUT045         3242040.69
# 3                       1997            OUT046         3370809.18
# 2                       1987            OUT013         3418605.81
# 5                       1999            OUT049         3495627.92
# 8                       2007            OUT017         3517541.62
# 7                       2004            OUT035         3607244.83
# 1                       1985            OUT027         5605149.77

# %% [markdown]
# #### Analyzing the sales grouped based on different outlet types.

# %%
df1 = new_bigmart_df.groupby('Outlet_Type')['Item_Outlet_Sales'].sum().reset_index().sort_values('Item_Outlet_Sales', ascending=True)
df1
# Out:
#          Outlet_Type  Item_Outlet_Sales
# 0      Grocery Store          582326.52
# 2  Supermarket Type2         2979587.34
# 3  Supermarket Type3         5605149.77
# 1  Supermarket Type1        20651870.05

# %%
import matplotlib
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#D4E166'
matplotlib.rcParams['font.weight'] = 'bold'

#fff2eb
#EACB01

#DBF406

# %%
plt.figure(figsize=(12, 7))
num_bars = len(df1.Outlet_Type)
colors = np.linspace(0.4, 0.8, num_bars)
plt.bar(df1.Outlet_Type, df1.Item_Outlet_Sales, width=0.5, color=plt.cm.Greens(colors))
plt.xlabel('Outlet Type', fontsize=12)
plt.ylabel('Sales in millions', fontsize=12)
plt.title('Sales by different Outlet Types', fontsize=14, fontweight="bold");

# %% [markdown]
# #### Best selling product outlet-wise

# %%
df2 = new_bigmart_df.groupby([new_bigmart_df.Outlet_Identifier,new_bigmart_df.Item_Type]).Item_Outlet_Sales.sum().reset_index()
df2
# Out:
#     Outlet_Identifier      Item_Type  Item_Outlet_Sales
# 0              OUT010   Baking Goods           19271.95
# 1              OUT010         Breads           12137.90
# 2              OUT010      Breakfast            4862.21
# 3              OUT010         Canned           18132.00
# 4              OUT010          Dairy           23488.33
# ..                ...            ...                ...
# 155            OUT049         Others           71869.12
# 156            OUT049        Seafood           18312.44
# 157            OUT049    Snack Foods          514414.48
# 158            OUT049    Soft Drinks          171728.12
# 159            OUT049  Starchy Foods           70509.51
#
# [160 rows x 3 columns]

# %%
max_sale_idx = df2.groupby('Outlet_Identifier')['Item_Outlet_Sales'].idxmax()

# Selecting the rows with the maximum sales for each outlet identifier
max_sale_rows = df2.loc[max_sale_idx]

# extracting the results into a new dataframe
max_sale_df = max_sale_rows[['Outlet_Identifier', 'Item_Type', 'Item_Outlet_Sales']]

# %%
max_sale_df
# Out:
#     Outlet_Identifier              Item_Type  Item_Outlet_Sales
# 13             OUT010            Snack Foods           41884.78
# 29             OUT013            Snack Foods          516571.47
# 45             OUT017            Snack Foods          519184.41
# 61             OUT018            Snack Foods          434897.70
# 70             OUT019  Fruits and Vegetables           39153.81
# 86             OUT027  Fruits and Vegetables          878990.19
# 109            OUT035            Snack Foods          537471.08
# 118            OUT045  Fruits and Vegetables          472593.68
# 134            OUT046  Fruits and Vegetables          483163.41
# 157            OUT049            Snack Foods          514414.48

# %%
plt.figure(figsize=(12, 7))
plt.bar(max_sale_df.Outlet_Identifier, max_sale_df.Item_Outlet_Sales, color="Green");
threshold = 400000
ax = plt.gca()
for rect, label in zip(ax.patches, max_sale_df['Item_Type']):
    height = rect.get_height()
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    if height < threshold:
        ax.text(x + width / 2, y + height , label, ha='center', va='bottom', rotation=90)
    else:
        ax.text(x + width / 2, y + height / 2, label, ha='center', va='center', rotation=90)
plt.xlabel('Outlet', fontsize=12)
plt.ylabel('Sales in millions', fontsize=12)
plt.title('Best selling product outlet-wise', fontsize=14, fontweight="bold");

# %% [markdown]
# #### Analyzing and plotting the quantity of item sold with respect to the item type.

# %%
new_bigmart_df['Item_Quantity_Sold']=new_bigmart_df['Item_Outlet_Sales']/new_bigmart_df['Item_MRP']
new_bigmart_df['Item_Quantity_Sold']=new_bigmart_df['Item_Quantity_Sold'].apply(np.floor)
new_bigmart_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat             0.02
# 1               DRC01         5.92          Regular             0.02
# 2               FDN15        17.50          Low Fat             0.02
# 3               FDX07        19.20          Regular             0.00
# 4               NCD19         8.93          Low Fat             0.00
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular             0.01
# 14200           FDD47         7.60          Regular             0.14
# 14201           NCO17        10.00          Low Fat             0.07
# 14202           FDJ26        15.30          Regular             0.00
# 14203           FDU37         9.50          Regular             0.10
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy    249.81            OUT049
# ...

# %%
df3=new_bigmart_df.groupby('Item_Type')['Item_Quantity_Sold'].sum().reset_index()
df3 = df3.sort_values('Item_Quantity_Sold', ascending=False)
df3
# Out:
#                 Item_Type  Item_Quantity_Sold
# 6   Fruits and Vegetables             29195.0
# 13            Snack Foods             28688.0
# 9               Household             21975.0
# 5            Frozen Foods             19860.0
# 3                  Canned             16034.0
# 4                   Dairy             15889.0
# 0            Baking Goods             15582.0
# 8      Health and Hygiene             12459.0
# 10                   Meat             10639.0
# 14            Soft Drinks             10396.0
# 1                  Breads              6083.0
# 7             Hard Drinks              5128.0
# 15          Starchy Foods              3947.0
# 11                 Others              3898.0
# 2               Breakfast              2570.0
# 12                Seafood              1418.0

# %%
plt.rcParams['axes.labelsize'] = 12
matplotlib.rcParams['figure.facecolor'] = 'w'
plt.figure(figsize=(16,8))
sns.barplot(y=df3.Item_Type, x=df3.Item_Quantity_Sold, palette='Greens_r', orient='h')
plt.title('Quantity of each Item sold', fontsize=14, fontweight="bold");

# %% [markdown]
# #### Examining the total type of products the BigMart grocery chain sells and their sales in percentage

# %%
itemUnique = new_bigmart_df.Item_Type.unique()
itemUnique
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
plt.figure(figsize=(12,8))
itemTypes=new_bigmart_df.Item_Type.value_counts()[:15]
labels = itemTypes.index[:15]
cmap=plt.get_cmap('Greens_r')
plt.pie(itemTypes, explode=np.full(15,0.2),autopct='%1.1f%%',labels=labels,shadow=True, colors=cmap(np.linspace(0, 1, len(itemTypes))))
plt.title('Item-Type-Wise Sales', fontsize=14, fontweight="bold", pad=20);

# %% [markdown]
# #### Analyzing the quantity of item sold based on their visibility in the stores.

# %%
df4=new_bigmart_df.groupby('Item_Type')['Item_Visibility','Item_Quantity_Sold'].agg({'Item_Visibility': 'mean', 'Item_Quantity_Sold': 'sum'})
df4
# Out:
# C:\Users\RADHASHREE\AppData\Local\Temp\ipykernel_24340\926072443.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df4=new_bigmart_df.groupby('Item_Type')['Item_Visibility','Item_Quantity_Sold'].agg({'Item_Visibility': 'mean', 'Item_Quantity_Sold': 'sum'})
#                        Item_Visibility  Item_Quantity_Sold
# Item_Type
# Baking Goods                  0.068066             15582.0
# Breads                        0.069615              6083.0
# Breakfast                     0.082204              2570.0
# Canned                        0.067306             16034.0
# Dairy                         0.071699             15889.0
# Frozen Foods                  0.067574             19860.0
# Fruits and Vegetables         0.068569             29195.0
# Hard Drinks                   0.065442              5128.0
# Health and Hygiene            0.056317             12459.0
# ...

# %%
plt.figure(figsize=(15,8))

plt.xlabel('Item Visibility', fontsize=15)
plt.ylabel('Item Quantity Sold', fontsize=15)

plt.rcParams.update({'text.color': "#420D09", 'axes.labelcolor': "#363636", 'font.weight': 'normal'})
plt.title("Comparison in Sales of different Items", fontsize=20)
#sns.scatterplot(df4.Item_Visibility.round(2), df4.Item_Quantity_Sold, color="#131E3A", hue=df4.index,palette='Dark2', s=100)
#sns.regplot(df4.Item_Visibility.round(2), df4.Item_Quantity_Sold, line_kws={'color': 'green'})

sns.regplot(data=df4, x='Item_Visibility', y='Item_Quantity_Sold', line_kws={'color': 'green'}, scatter_kws={'color': "#131E3A", 's': 100})

plt.legend(loc='upper right', ncol=2);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
correlation = df4['Item_Visibility'].corr(df4['Item_Quantity_Sold']).round(4)
correlation
# Out:
# -0.1081

# %%
import scipy.stats as stats

# Assuming you have the x and y data stored in separate variables, as in your previous code
x = df4.Item_Visibility.round(2)
y = df4.Item_Quantity_Sold

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# Access the slope
print("Slope of the regression line:", slope)
# Out:
# Slope of the regression line: -117134.99999999975

# %% [markdown]
# From the above graph and inferences, we can conclude that every product approxamitely similar visibility opportunity and that more visibility doesn't guarantee better the sales.

# %% [markdown]
# #### Analyzing and plotting how the sales are affected based on the outlet size.

# %%
df5=new_bigmart_df.groupby('Outlet_Size')['Item_Visibility','Item_Outlet_Sales'].sum()
df5
# Out:
# C:\Users\RADHASHREE\AppData\Local\Temp\ipykernel_24340\4286706988.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df5=new_bigmart_df.groupby('Outlet_Size')['Item_Visibility','Item_Outlet_Sales'].sum()
#              Item_Visibility  Item_Outlet_Sales
# Outlet_Size
# High                  376.66        10477212.00
# Medium                278.55        12080365.03
# Small                 282.13         7261356.65

# %%
plt.figure(figsize=(12,8))
color=['#00A36C','#033E3E','#006A4E']
labels=['Medium', 'High', 'Small']
exp_val=[0.05,0.1,0.1]
textprops={'fontsize':12, 'color':'white'}
sizes=new_bigmart_df.Outlet_Size.unique()
plt.pie(df5.Item_Outlet_Sales, explode=exp_val, labels=labels, autopct='%1.1f%%', shadow=True, radius=0.8, startangle=90, colors=color,textprops=textprops)
plt.title('Sales based on Outlet size', fontsize=14, fontweight="bold")
plt.legend();

# %% [markdown]
# #### Checking the sales of each category Outlet_type-wise

# %%
df6 = new_bigmart_df.groupby(['Outlet_Type', 'Item_Type'])['Item_MRP'].max().reset_index()
df6
# Out:
#           Outlet_Type      Item_Type  Item_MRP
# 0       Grocery Store   Baking Goods    263.86
# 1       Grocery Store         Breads    260.46
# 2       Grocery Store      Breakfast    233.93
# 3       Grocery Store         Canned    266.59
# 4       Grocery Store          Dairy    266.69
# ..                ...            ...       ...
# 59  Supermarket Type3         Others    253.50
# 60  Supermarket Type3        Seafood    240.49
# 61  Supermarket Type3    Snack Foods    265.06
# 62  Supermarket Type3    Soft Drinks    261.39
# 63  Supermarket Type3  Starchy Foods    263.53
#
# [64 rows x 3 columns]

# %%
plt.figure(figsize=(30, 13))
ax.set_facecolor("#CEF1E9")
plt.xlabel("Item Type",fontsize=20)
plt.ylabel("Item MRP",fontsize=20)
plt.title("Item MRP by Item Type and Outlet Type", fontsize=14, fontweight="bold")
custom_palette = ['#AAF0D1','#00A36C','#006A4E','#033E3E']
sns.barplot(x=df6.Item_Type, y=df6.Item_MRP, hue=df6.Outlet_Type,palette=custom_palette)
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.ylim(bottom=200);

# %% [markdown]
# #### Plotting average visbility of each item type

# %%
df7 = new_bigmart_df.groupby(['Item_Type'])['Item_Visibility'].mean().reset_index()
df7
# df7.sort_values('Item_Visibility', ascending=False)
# Out:
#                 Item_Type  Item_Visibility
# 0            Baking Goods         0.068066
# 1                  Breads         0.069615
# 2               Breakfast         0.082204
# 3                  Canned         0.067306
# 4                   Dairy         0.071699
# 5            Frozen Foods         0.067574
# 6   Fruits and Vegetables         0.068569
# 7             Hard Drinks         0.065442
# 8      Health and Hygiene         0.056317
# 9               Household         0.059761
# 10                   Meat         0.059755
# 11                 Others         0.056786
# 12                Seafood         0.070337
# 13            Snack Foods         0.067652
# 14            Soft Drinks         0.064959
# 15          Starchy Foods         0.066877

# %%
# df7.sample(20)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15, 10))
ax1 = fig.add_subplot(121, polar=True)
ax2 = fig.add_subplot(122, polar=True)

ax1.set_facecolor("#CEF1E9")
ax2.set_facecolor("#CEF1E9")

# Ploting the bar chart
theta = [i * 2 * np.pi / len(df7.Item_Type) for i in range(len(df7.Item_Type))]
width = 2 * np.pi / len(df7.Item_Type)
bars = ax1.bar(theta, df7.Item_Visibility, width=width, alpha=0.75, color='green')

ax1.set_xticks(theta)
ax1.set_xticklabels(df7.Item_Type)

# Ploting the pie chart
explode = [0.1] * len(df7.Item_Type)
colors = plt.cm.tab20c(np.linspace(0, 1, len(df7.Item_Type)))
wedges, texts, autotexts = ax2.pie(df7.Item_Visibility, labels=df7.Item_Type, colors=colors, explode=explode,
                                   autopct='%1.1f%%', shadow=True, startangle=90)

# Adjusting the text color of pie chart
for text in autotexts:
    text.set_color('white')

# Setting the aspect ratio to make the polar plots circular
ax1.set_aspect('equal')
ax2.set_aspect('equal')

plt.suptitle("Item Visibility by Type", fontsize=20)
plt.show()

# %% [markdown]
# #### Analyzing the effect of fat content of sales of that item.

# %%
df8=new_bigmart_df.Item_Fat_Content.unique()
df8
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
arr=np.array([new_bigmart_df[new_bigmart_df.Item_Fat_Content=="Low Fat"].Item_Outlet_Sales.sum(),new_bigmart_df[new_bigmart_df.Item_Fat_Content=="Regular"].Item_Outlet_Sales.sum()])
arr
# Out:
# array([19166598.61, 10652335.07])

# %%
# plt.style.use('bmh')

# %%
plt.figure(figsize=(15,8))
color=['#3F704D','#EDDA74']
exp_val=[0.1,0.1]
textprops={'fontsize':12}
plt.pie(arr, labels=df8, colors=color, explode=exp_val, shadow=True, autopct="%1.1f%%", textprops=textprops, radius=0.8, startangle=90)
plt.title("Comparison in Sales of Items based on Fat Content", fontsize=14)
plt.legend();

# %% [markdown]
# ### MRP based on outlet location type

# %%
q11_df=new_bigmart_df.groupby(['Outlet_Location_Type','Item_Type'])['Item_MRP'].mean().reset_index()

# %%
plt.figure(figsize=(25, 10))
ax.set_facecolor("#CEF1E9")
custom_palette = ['#AAF0D1','#00A36C','#006A4E','#033E3E']
sns.barplot(x=q11_df.Item_Type, y=q11_df.Item_MRP, hue=q11_df.Outlet_Location_Type, palette=custom_palette)
plt.ylim(120,150)
# Out:
# (120.0, 150.0)

# %% [markdown]
# ## Inferences and Conclusions

# %% [markdown]
# From the above graphs and inferences made with reference to the dataset, we can draw the following conclusions for the questions asked about the data:
#
# * Total revenue of BigMart grocery chain is approximately 30 million dollars.
# * BigMart caters 16 different category of products.
# * Older establishment doesn't guarantee better sales.
# * Type 1 Supermarkets have the best sales.
# * What product is in higher demand and hence should be stocked more in which outlet.
# * Fruits and Vegetables are the hero product of BigMart grocery chain.
# * More visibility doesn't guarantee better the sales.
# * There is low to no variance in price of products based on Outlet type.
# * Breakfast items have the overall highest average visibility.
# * Low fat items are in higher demand.
# * There is some variance in price based on outlet location.

# %% [markdown]
# ## References

# %% [markdown]
# 1. For some coding related doubts reffered - https://datatofish.com/
# 2. For knowing more about pandas and it's functions in detail - https://pandas.pydata.org
# 3. For knowing more about matplotlib - https://matplotlib.org
# 4. For knowing more about seaborn - https://seaborn.pydata.org/
